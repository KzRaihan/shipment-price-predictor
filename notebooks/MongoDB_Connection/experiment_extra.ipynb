# %% [markdown]
# ### Topic: Extra Experiment of MongoDB

# %%
# import os
# from dotenv import load_dotenv
# import pymongo

# load_dotenv()
# client = pymongo.MongoClient(os.getenv("MONGODB_URL"))
# coll = client["Shipment_DB"]["shipment_collection"]

# print("rows:", coll.count_documents({}))
# print("columns:", list(coll.find_one().keys()))

# %%
print("columns length :", len(coll.find_one().keys()))
# Out:
# columns length : 21

# %%
# import os
# from dotenv import load_dotenv
# import pymongo

# load_dotenv()

# # 1) See what both variables actually contain
# print("MONGO_DB_URL  =", os.getenv("MONGO_DB_URL"))
# print("MONGODB_URL   =", os.getenv("MONGODB_URL"))

# # 2) Read the DB exactly the way demo.py does
# client = pymongo.MongoClient(os.getenv("MONGO_DB_URL"))
# coll = client["Shipment_DB"]["shipment_collection"]
# print("rows (pipeline view):", coll.count_documents({}))
